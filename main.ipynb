# %%
#importing necessary libraries
import nltk
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import cosine_similarity
import heapq
import numpy as np
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Step 1: Sentence Segmentation
#seperating sentences using spacy (punctuation marks work like delimitters. Sentences just maintains them as seperate sentences
def process_text(text):
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]
    return sentences[0]

# %%
# step 2: Tokenization
def tokenize_text(text):
    text = process_text(text)
    tokenized_sents = nltk.sent_tokenize(text)
    tokenized_sents = [nltk.word_tokenize(sent) for sent in tokenized_sents]
    tokenized_sents = [remove_stop_words(tokens) for tokens in tokenized_sents]

    return tokenized_sents

# %%
# Step 3: removing stop words according to Buckely list of stop words

#for which we ned to first take the buckley stopword list as a list
with open("./Data/Buckley-Salton-stopword-list.txt", "r") as words:
	lines = words.readlines()
stop_words =[]
for words in lines:
    as_list = words.split(",")
    stop_words.append(as_list[0].replace("\n", ""))

# %%
def remove_stop_words(text):
    return [word for word in text if word.lower() not in stop_words]

# %%
# Step 4:  Extracting sentences 
def F_first_K_Sents(text, f):
    return text[:f]

# selecting only important parts of sentences and making a score
def SelectImpSentences(scores, N, sentences):
    selected_indices = heapq.nlargest(N, scores, key=scores.get)
    selected_sentences = [sentences[i] for i in selected_indices]
    return [sentence for sublist in selected_sentences for sentence in sublist]

# %%
# Step 5: combining all fucntions and finding the score of best sentences
def extractiveApproach(dataset, f, N):
    output_dataset = []
    for input_text in dataset:
        important_sentences = []

        #calling the tokenization function
        tokenized_sents = tokenize_text(input_text)

        # calling the Sentence Extracting fucntion
        first_k_sents = F_first_K_Sents(tokenized_sents, f)
        
        #finding the best score words and sentences
        sentence_embeddings = [np.mean(np.array([token.vector for token in nlp(' '.join(tokens))]), axis=0) for tokens in first_k_sents]
        similarity_matrix = cosine_similarity(sentence_embeddings, sentence_embeddings)
        
        #findng the important sentence
        for i, sent in enumerate(first_k_sents):
            scores = {j: similarity_matrix[i][j] for j in range(len(first_k_sents))}
            important_sentences.append(sent)
        
        selected_sentences = SelectImpSentences(scores, N, first_k_sents)
        summary = ' '.join(selected_sentences)
        
        output_dataset.append(summary)
    
    return output_dataset

# %%
with open('Data/2007/2007_acura_rdx', "r") as words:
	lines = words.readlines()
text =[]
for words in lines:
    as_list = words.split(",")
    text.append(as_list[0].replace("\n", ""))

f = 2  # Number of sentences to consider
N = 5  # Number of words per sentence

summarized_dataset = extractiveApproach(text, f, N)

# %%
summarized_dataset
# Out:
# ['< DOCNO > 2007_acura_rdx < /DOCNO >',
#  '< DOC >',
#  '< DATE > 08/28/2009 < /DATE >',
#  '< AUTHOR > RDX LOVER < /AUTHOR >',
#  "< TEXT > 'm sales rep drive approximately 40",
#  '< FAVORITE > Blue Tooth Technology Backup camera side mirror tilts',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/27/2009 < /DATE >',
#  '< AUTHOR > Critical < /AUTHOR >',
#  '< TEXT > Absolutely great car .',
#  '< FAVORITE > Tech package',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/25/2009 < /DATE >',
#  '< AUTHOR > rcizme < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Premium sound system',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/21/2009 < /DATE >',
#  '< AUTHOR > Chapel Hill < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > * turbo charge engine ; all-wheel drive',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/08/2009 < /DATE >',
#  '< AUTHOR > ever_green < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Turbo charged',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/07/2009 < /DATE >',
#  '< AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > comfortable seats',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/04/2009 < /DATE >',
#  '< AUTHOR > LoveACURA < /AUTHOR >',
#  '< TEXT > owned Hondas years strayed AUDI years ago .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/21/2009 < /DATE >',
#  '< AUTHOR > Mark < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Styling < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/03/2008 < /DATE >',
#  '< AUTHOR > HondaMoCoFan < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/01/2008 < /DATE >',
#  '< AUTHOR > johnnymauler < /AUTHOR >',
#  '< TEXT > owning vehicle year tired responsive automatic transmission .',
#  '< FAVORITE > Turbo',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/11/2007 < /DATE >',
#  '< AUTHOR > jingo < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/07/2007 < /DATE >',
#  '< AUTHOR > RDX_75 < /AUTHOR >',
#  "< TEXT > Purchased vehicle week ago n't pleased .",
#  '< FAVORITE > < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/02/2007 < /DATE >',
#  '< AUTHOR > NorCalJ < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Heated seats',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/30/2006 < /DATE >',
#  '< AUTHOR > Dzenan < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Turbo',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/28/2006 < /DATE >',
#  '< AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/26/2006 < /DATE >',
#  '< AUTHOR > changomo < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Excellent voice recognition system navi',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/19/2006 < /DATE >',
#  '< AUTHOR > Ben < /AUTHOR >',
#  '< TEXT > RDX tech package 2 months .',
#  '< FAVORITE > Bluetooth phone',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/18/2006 < /DATE >',
#  '< AUTHOR > palsons99 < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Ability speak commands car radio station temperature adds fun drive quotient. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/11/2006 < /DATE >',
#  '< AUTHOR > Emile < /AUTHOR >',
#  "< TEXT > 've RDX month",
#  '< FAVORITE > Navigation system',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/10/2006 < /DATE >',
#  '< AUTHOR > Josho < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > AWD standard',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/10/2006 < /DATE >',
#  '< AUTHOR > BVaughn < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Soft',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/09/2006 < /DATE >',
#  '< AUTHOR > wendy < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Acceleration',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/07/2006 < /DATE >',
#  '< AUTHOR > Mi Ami < /AUTHOR >',
#  '< TEXT > open door high tech monster made choice .',
#  '< FAVORITE > talks understand commands. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 12/06/2006 < /DATE >',
#  '< AUTHOR > ECB < /AUTHOR >',
#  '< TEXT > Purchased mine 2 weeks ago put 800 miles .',
#  '< FAVORITE > RDX handles sports car .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/27/2006 < /DATE >',
#  '< AUTHOR > Brillo < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/27/2006 < /DATE >',
#  '< AUTHOR > Rusty < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/25/2006 < /DATE >',
#  '< AUTHOR > Bink < /AUTHOR >',
#  '< TEXT > Poor gas mileage premium - 18.3 MPG freeway driving .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/23/2006 < /DATE >',
#  '< AUTHOR > harvey agustin < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Sports mode paddle shifters favorite features car. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/21/2006 < /DATE >',
#  '< AUTHOR > dorianf < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/21/2006 < /DATE >',
#  '< AUTHOR >',
#  "< TEXT > `` love '' RDX highway month ago .",
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/19/2006 < /DATE >',
#  '< AUTHOR > Robert Small < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Radio. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/17/2006 < /DATE >',
#  '< AUTHOR > Curtis < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > SH-AWD',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/15/2006 < /DATE >',
#  '< AUTHOR > Charles Hatley < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Favorite features awesome navi system',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/15/2006 < /DATE >',
#  '< AUTHOR > Charles Hatley < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Suggested Improvements < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/14/2006 < /DATE >',
#  '< AUTHOR > BornToDrive < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Audio commands',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/12/2006 < /DATE >',
#  '< AUTHOR >',
#  '< TEXT > Purchased RDX weeks ago .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/08/2006 < /DATE >',
#  '< AUTHOR > Tami < /AUTHOR >',
#  '! < TEXT > bought RDX weeks ago love !',
#  '< FAVORITE > Navigation',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/06/2006 < /DATE >',
#  '< AUTHOR > Tami < /AUTHOR >',
#  '< TEXT > Love RDX/ Tech Package .',
#  '< FAVORITE > Navigation',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/05/2006 < /DATE >',
#  '< AUTHOR > mike < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > technology .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/03/2006 < /DATE >',
#  '< AUTHOR > dostoyevsky77 < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/01/2006 < /DATE >',
#  '< AUTHOR > black satin < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Turbo',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/01/2006 < /DATE >',
#  '< AUTHOR > pete < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > wheel drive',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/28/2006 < /DATE >',
#  '< AUTHOR > AZ < /AUTHOR >',
#  "< TEXT > 've vehicle months ca n't find ( 2500 miles ) .",
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/25/2006 < /DATE >',
#  '< AUTHOR > Vern Florida < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/22/2006 < /DATE >',
#  '< AUTHOR > rdxster < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/22/2006 < /DATE >',
#  '< AUTHOR > Michael < /AUTHOR >',
#  '< TEXT > purchased RDX w/ tech - worth additional $ 3k .',
#  '< FAVORITE > Love voice-activated navigation system .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/20/2006 < /DATE >',
#  '< AUTHOR > def < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Comfortable seats .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/20/2006 < /DATE >',
#  '< AUTHOR > diamondpearl < /AUTHOR >',
#  '< TEXT >',
#  "< FAVORITE > Ca n't",
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/19/2006 < /DATE >',
#  '< AUTHOR > Zel < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Technology package & sound system .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/12/2006 < /DATE >',
#  '< AUTHOR > gomboy60 < /AUTHOR >',
#  '< TEXT > day happy car .',
#  '< FAVORITE > Awesome interior sharp ext .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/11/2006 < /DATE >',
#  '< AUTHOR > idr < /AUTHOR >',
#  '< TEXT > buying',
#  '< FAVORITE > Great ride quality .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/09/2006 < /DATE >',
#  '< AUTHOR > Falloonrd1 < /AUTHOR >',
#  '< TEXT > impressed vehicle .',
#  '< FAVORITE > Navigation',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/09/2006 < /DATE >',
#  '< AUTHOR > patentcad < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Interior design phenomenal .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/08/2006 < /DATE >',
#  '< AUTHOR > Bryan < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Backup cam passenger mirror tilt-down reverse',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/08/2006 < /DATE >',
#  '< AUTHOR > susan < /AUTHOR >',
#  '< TEXT > Fun car drive traded 2002 TL sort nervous SUV regrets .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/08/2006 < /DATE >',
#  '< AUTHOR > stevieharris < /AUTHOR >',
#  '< TEXT > Neat car',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/07/2006 < /DATE >',
#  '< AUTHOR > Acuralover < /AUTHOR >',
#  "< TEXT > 've owned 5 Honda Acura products",
#  '< FAVORITE > Fabulous interior technology features .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/06/2006 < /DATE >',
#  '< AUTHOR > < /AUTHOR >',
#  '< TEXT > Great pickup handling SUV .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/04/2006 < /DATE >',
#  '< AUTHOR > NYC=Fun < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Tech Package .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/04/2006 < /DATE >',
#  '< AUTHOR > Dan < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Quickness',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/03/2006 < /DATE >',
#  '< AUTHOR > drtimko < /AUTHOR >',
#  '< TEXT > Great car bought week .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/03/2006 < /DATE >',
#  '< AUTHOR > Bill < /AUTHOR >',
#  '< TEXT > driven Audi A8s 9 years',
#  '< FAVORITE > Killer sound system',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/28/2006 < /DATE >',
#  '< AUTHOR > NemoUmbra < /AUTHOR >',
#  '< TEXT > Car drives nicely sportier ride bit harsh times normal day day driving .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/28/2006 < /DATE >',
#  '< AUTHOR > Wedgebolt < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/27/2006 < /DATE >',
#  '< AUTHOR > TColeman < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Back-up camera',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/27/2006 < /DATE >',
#  '< AUTHOR > Ed Illinois < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Love voice recognition',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/25/2006 < /DATE >',
#  '< AUTHOR > CJ < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Navi',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/24/2006 < /DATE >',
#  '< AUTHOR > Fast Freddy < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Technology package',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/22/2006 < /DATE >',
#  '< AUTHOR > Pacific < /AUTHOR >',
#  '< TEXT > great car',
#  '< FAVORITE > Navigation system',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/21/2006 < /DATE >',
#  '< AUTHOR > Stevie < /AUTHOR >',
#  '< TEXT > impressed happy car .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/20/2006 < /DATE >',
#  '< AUTHOR > Cdangelo < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Great performance handling. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/18/2006 < /DATE >',
#  '< AUTHOR > Lewis < /AUTHOR >',
#  "< TEXT > 've RDX weeks love !",
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/12/2006 < /DATE >',
#  '< AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Tech package : Bluetooth phone',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/09/2006 < /DATE >',
#  '< AUTHOR > SyracuseAcura < /AUTHOR >',
#  '< TEXT > extensive driving noted RDX shines wide range driving scenarios .',
#  '< FAVORITE > < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/07/2006 < /DATE >',
#  '< AUTHOR > Andy < /AUTHOR >',
#  '< TEXT > moment test drove vehicle impressed .',
#  '< FAVORITE > F1 paddle shifters',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/05/2006 < /DATE >',
#  '< AUTHOR > betsy_me < /AUTHOR >',
#  '< TEXT > Car great gas mileage terrible .',
#  '< FAVORITE > Style',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/04/2006 < /DATE >',
#  '< AUTHOR > Alex Harris < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Handling',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/02/2006 < /DATE >',
#  '< AUTHOR > Bob < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/30/2006 < /DATE >',
#  '< AUTHOR > William < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Turbo',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/27/2006 < /DATE >',
#  '< AUTHOR > Mark < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/21/2006 < /DATE >',
#  '< AUTHOR > Eric < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Technology amazing- stereo',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/20/2006 < /DATE >',
#  '< AUTHOR > RDX < /AUTHOR >',
#  '< TEXT > bought Colorado .',
#  '< FAVORITE > Interior',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/20/2006 < /DATE >',
#  '< AUTHOR > Eric < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/17/2006 < /DATE >',
#  '< AUTHOR > rskdsk < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Interior confort handeling < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/12/2006 < /DATE >',
#  '< AUTHOR > rsbell < /AUTHOR >',
#  "< TEXT > 've owned vehicle 1 day",
#  '< FAVORITE > Tech package !',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/17/2008 < /DATE >',
#  '< AUTHOR > crvols < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Performance',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/31/2008 < /DATE >',
#  '< AUTHOR > sad rdx < /AUTHOR >',
#  "< TEXT > careful RDX : front end problem addressed - feels shocks n't .",
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/04/2008 < /DATE >',
#  '< AUTHOR > Unhappy < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > XM nice headlights aimed right. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/23/2008 < /DATE >',
#  '< AUTHOR > dpo < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/22/2008 < /DATE >',
#  '< AUTHOR > michael < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 03/20/2008 < /DATE >',
#  '< AUTHOR > PaulT < /AUTHOR >',
#  '< TEXT > Test drove Mercedes',
#  '< FAVORITE > SH-AWD',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 03/19/2008 < /DATE >',
#  '< AUTHOR > Chad < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Acceleration',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/16/2008 < /DATE >',
#  '< AUTHOR > Chuck W. < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Paddle shifters sports-car feel .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/30/2007 < /DATE >',
#  '< AUTHOR > Henry FL1 < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Nav',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/18/2007 < /DATE >',
#  '< AUTHOR > JimTex < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 11/14/2007 < /DATE >',
#  '< AUTHOR > FTNSS1 < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > SH-AWD',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/24/2007 < /DATE >',
#  '< AUTHOR > dk168 < /AUTHOR >',
#  '< TEXT > car year .',
#  '< FAVORITE > Love GPS real-time traffic .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/18/2007 < /DATE >',
#  '< AUTHOR > CD < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/17/2007 < /DATE >',
#  'Wood < /AUTHOR > < AUTHOR > .',
#  '< TEXT >',
#  '< FAVORITE > Turbo power technology system - navigation',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/11/2007 < /DATE >',
#  '< AUTHOR > kcosta < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Navigation',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/07/2007 < /DATE >',
#  '< AUTHOR > CAS < /AUTHOR >',
#  '< TEXT > initial questions primarily due problems bluetooth',
#  '< FAVORITE > Turbo',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/05/2007 < /DATE >',
#  '< AUTHOR > FitnessCC < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Handling',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 10/05/2007 < /DATE >',
#  '< AUTHOR > UTRDX < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Seats',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/30/2007 < /DATE >',
#  '< AUTHOR > lrpba300 < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > SH-AWD',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/24/2007 < /DATE >',
#  '< AUTHOR > Garg < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/20/2007 < /DATE >',
#  '< AUTHOR > Carey < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > XM radio',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 09/10/2007 < /DATE >',
#  '< AUTHOR > CB < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Tech package good < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/28/2007 < /DATE >',
#  '< AUTHOR > Spoiled < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > SH AWD',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/21/2007 < /DATE >',
#  '< AUTHOR > MattAZ < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/10/2007 < /DATE >',
#  '< AUTHOR > judy < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 08/06/2007 < /DATE >',
#  '< AUTHOR > Matt < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Handling',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/31/2007 < /DATE >',
#  '< AUTHOR > remke44 < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Great ride handling .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/28/2007 < /DATE >',
#  '< AUTHOR > Henry < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Seats',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/27/2007 < /DATE >',
#  '< AUTHOR > RDXer < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Standard equipment',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/19/2007 < /DATE >',
#  '< AUTHOR > Paul < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Love turbo sound system close .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/17/2007 < /DATE >',
#  '< AUTHOR > wsdyer < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Zoned air conditioning',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 07/14/2007 < /DATE >',
#  '< AUTHOR > Disappointed Owner < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/23/2007 < /DATE >',
#  '< AUTHOR > lukeivic < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Navigation',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/20/2007 < /DATE >',
#  '< AUTHOR > jfc < /AUTHOR >',
#  '< TEXT > Acceleration',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/17/2007 < /DATE >',
#  '< AUTHOR > swiftfootedperseus < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/17/2007 < /DATE >',
#  '< AUTHOR > acurafan < /AUTHOR >',
#  '< TEXT > purchased Acura RDX Tech Package .',
#  '< FAVORITE > Tech package',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/15/2007 < /DATE >',
#  '< AUTHOR > Bish < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/13/2007 < /DATE >',
#  '< AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/12/2007 < /DATE >',
#  '< AUTHOR > Lainey < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Bluetooth',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/11/2007 < /DATE >',
#  '< AUTHOR > Luis < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Bluetooth',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/06/2007 < /DATE >',
#  '< AUTHOR > cnmec < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 06/01/2007 < /DATE >',
#  '< AUTHOR > Lainey < /AUTHOR >',
#  "< TEXT > 've car wanted size wanted .",
#  '< FAVORITE > Technology package. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/25/2007 < /DATE >',
#  '< AUTHOR > rdx < /AUTHOR >',
#  '< TEXT > 18',
#  '< FAVORITE > < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/23/2007 < /DATE >',
#  '< AUTHOR > Alex M. < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Fantastic nav system',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/19/2007 < /DATE >',
#  '< AUTHOR > RDX Fan < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Technology package adds toys .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/18/2007 < /DATE >',
#  '< AUTHOR > Kathy < /AUTHOR >',
#  '< TEXT > weeks son driving researching types SUVs',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/14/2007 < /DATE >',
#  '< AUTHOR > Vivian < /AUTHOR >',
#  '< TEXT > Test drove BMW X3',
#  '< FAVORITE > Everything. < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/03/2007 < /DATE >',
#  '< AUTHOR > Trailman < /AUTHOR >',
#  '< TEXT > happy .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/02/2007 < /DATE >',
#  '< AUTHOR > Greenboy < /AUTHOR >',
#  '< TEXT > car weekend great time .',
#  '< FAVORITE > Rear view camera live traffic GPS .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 05/01/2007 < /DATE >',
#  '< AUTHOR > Albert < /AUTHOR >',
#  '< TEXT > RDX quick nimble',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/19/2007 < /DATE >',
#  '< AUTHOR > Sutter A. < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Backup cameras .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/18/2007 < /DATE >',
#  '< AUTHOR > Mark < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Great stereo system .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/17/2007 < /DATE >',
#  '< AUTHOR > dfjcu1979 < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Tech package !',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/13/2007 < /DATE >',
#  '< AUTHOR > Rob < /AUTHOR >',
#  '< TEXT > driving large SUV years',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/09/2007 < /DATE >',
#  '< AUTHOR > Lori < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Great interior design ( ergonomic ) .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/08/2007 < /DATE >',
#  '< AUTHOR > kenjr < /AUTHOR >',
#  '< TEXT > Drove home RDX w/Tech days ago absolutely loving vehicle .',
#  '< FAVORITE > Tech package question - voice command spot',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/04/2007 < /DATE >',
#  '< AUTHOR > love Acura < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 04/02/2007 < /DATE >',
#  '< AUTHOR > steve < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Tons technology',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 03/29/2007 < /DATE >',
#  '< AUTHOR > John K. < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Sportscar-like handling',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 03/22/2007 < /DATE >',
#  '< AUTHOR > Jappi < /AUTHOR >',
#  '< TEXT > Honestly',
#  '< FAVORITE > Turbo lag - handles car .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 03/14/2007 < /DATE >',
#  '< AUTHOR > Tom & # 039 ; RDX < /AUTHOR >',
#  '< TEXT > Love SUV/Car .',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 03/06/2007 < /DATE >',
#  '< AUTHOR > Michael < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 03/03/2007 < /DATE >',
#  '< AUTHOR > acurardx2 < /AUTHOR >',
#  '< TEXT > Plain super',
#  '< FAVORITE > Interior design',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/25/2007 < /DATE >',
#  '< AUTHOR > mlb11 < /AUTHOR >',
#  "< TEXT > 've owned RDX month",
#  '< FAVORITE > Handling',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/19/2007 < /DATE >',
#  '< AUTHOR > Baldegl < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Nav',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/15/2007 < /DATE >',
#  '< AUTHOR > CJ < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Heated seats & mirrors',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/14/2007 < /DATE >',
#  '< AUTHOR > Stacie < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > AWD',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/06/2007 < /DATE >',
#  '< AUTHOR > John < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Heated seats',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 02/03/2007 < /DATE >',
#  '< AUTHOR > Mike < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Tech features',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/30/2007 < /DATE >',
#  '< AUTHOR > AJ22Flight < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Perforated leather seats',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/27/2007 < /DATE >',
#  '< AUTHOR > Diego < /AUTHOR >',
#  '< TEXT > car .',
#  '< FAVORITE > Motor',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/25/2007 < /DATE >',
#  '< AUTHOR > SJN < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > SH-AWD',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/24/2007 < /DATE >',
#  '< AUTHOR > Janice < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Auto windows',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/20/2007 < /DATE >',
#  '< AUTHOR > cg < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > comfortable seats',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/19/2007 < /DATE >',
#  '< AUTHOR > Mary < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Love turbo shift paddles .',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/18/2007 < /DATE >',
#  '< AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/16/2007 < /DATE >',
#  '< AUTHOR > binh < /AUTHOR >',
#  '< TEXT > wife absolutely love car .',
#  '< FAVORITE > Nav',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/15/2007 < /DATE >',
#  '< AUTHOR > HowdyKeith < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/15/2007 < /DATE >',
#  '< AUTHOR > GNV < /AUTHOR >',
#  '< TEXT > Technology package superb .',
#  '< FAVORITE > Technology package < /FAVORITE >',
#  '< /DOC >',
#  '< DOC >',
#  '< DATE > 01/13/2007 < /DATE >',
#  '< AUTHOR > Grizzly < /AUTHOR >',
#  '< TEXT >',
#  '< FAVORITE > Technology package .',
#  '< /DOC >']

# %%
from collections import defaultdict
from pathlib import Path
import pandas as pd

my_dir_path = "./Data/2007"

results = defaultdict(list)
for file in Path(my_dir_path).iterdir():
    with open(file, "r") as file_open:
        results["file_name"].append(file.name)
        results["text"].append(file_open.read())
df = pd.DataFrame(results)

# %%
df.head()
# Out:
#         file_name                                               text
# 0  2007_acura_mdx  \nFlewByU\nI just moved to Germany two months ...
# 1  2007_acura_rdx  <DOCNO>2007_acura_rdx</DOCNO>\n<DOC>\n<DATE>08...
# 2   2007_acura_rl  <DOCNO>2007_acura_rl</DOCNO>\n<DOC>\n<DATE>09/...
# 3   2007_acura_tl  <DOCNO>2007_acura_tl</DOCNO>\n<DOC>\n<DATE>09/...
# 4  2007_acura_tsx  <DOCNO>2007_acura_tsx</DOCNO>\n<DOC>\n<DATE>09...

# %%
df.to_csv('2007-car-reviews.csv', index = False)
